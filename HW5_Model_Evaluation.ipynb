# %% [markdown]
# # Homework Assignment 5: Model Evaluation
# As in the previous assignments, in this homework assignment you will continue your exploration of the [SWAN-SF Dataset](https://doi.org/10.7910/DVN/EBCFKM), described in the paper found [here](https://doi.org/10.1038/s41597-020-0548-x).
#
#
# This assignment will utilize a copy of the extracted feature dataset we have been working with. The dataset has been processed by performing outlier clipping, z-score and range scaling, and forward feature selection to select 20 features. We are now going to utilize more than one partition worth of data, so for the z-score and range scaling, the mean, standard deviation, minimum, and maximum were calculated using data from both partitions so that a global scaling can be performed on each partition.
#
# ---

# %% [markdown]
# ## Step 1: Downloading the Data
#
# This assignment will continue to only use [Partition 1](https://dataverse.harvard.edu/api/access/datafile/:persistentId?persistentId=doi:10.7910/DVN/EBCFKM/BMXYCB) and will add the use of [Partition 2](https://dataverse.harvard.edu/api/access/datafile/:persistentId?persistentId=doi:10.7910/DVN/EBCFKM/TCRPUD) as a testing set.
#
# ---
#
# For this assignment, cleaning, transforming, and normalization of the data has been completed using both partitions to find the various minimum, maximum, standard deviation, and mean values needed to perform these operations. Recall from lecture that we should not perform these operations on each partition individually, but as a whole as there may(will) be different values for these in different partitions.
#
# For example, if we perform simple range scaling on each partition individually and we see a range of 0 to 100 in one partition and 0 to 10 in another. After individual scaling the values with 100 in the first would be mapped to 1 just like the values that had 10 in the second. This can cause serious performance problems in your model, so I have made sure that the normalization was treated properly for you.
#
# Below you will find the full partitions and `toy` sampled data from each partition, where only 20 samples from each of our 5 classes have been included in the data.
#
# #### Full
# - [Full Normalized Partition 1 feature dataset](http://dmlab.cs.gsu.edu/solar/data/normalized_partition1ExtractedFeatures.csv)
# - [Full Normalized Partition 2 feature dataset](http://dmlab.cs.gsu.edu/solar/data/normalized_partition2ExtractedFeatures.csv)
#
# #### Toy
# - [Toy Normalized Partition 1 feature dataset](http://dmlab.cs.gsu.edu/solar/data/toy_normalized_partition1ExtractedFeatures.csv)
# - [Toy Normalized Partition 2 feature dataset](http://dmlab.cs.gsu.edu/solar/data/toy_normalized_partition2ExtractedFeatures.csv)
#
# Now that you have the two files, you should load each into a Pandas DataFrame using the [pandas.read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) method.
#
# ---

# %% [markdown]
# ### Evaluation Metric
#
# For each of the models we evaluate in this assignmnet, you will calculate the True Skill Statistic score using the test data from Partition 2 to determine which model performs the best for classifying the positive flaring class.
#
#     True skill statistic (TSS) = TPR + TNR - 1 = TPR - (1-TNR) = TPR - FPR
#
# Where:
#
#     True positive rate (TPR) = TP/(TP+FN) Also known as recall or sensitivity
#     True negative rate (TNR) = TN/(TN+FP) Also known as specificity or selectivity
#     False positive rate (FPR) = FP/(FP+TN) = (1-TNR) Also known as fall-out or false alarm ratio
#
#
# **Recall**
#
#     True positive (TP)
#     True negative (TN)
#     False positive (FP)
#     False negative (FN)
#
# See [confusion matrix](https://en.wikipedia.org/wiki/Confusion_matrix) for more information.
#
# Below is a function implemented to provide your score for each model.

# %%
import os
import itertools
import pandas as pd
from pandas import DataFrame 
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import chi2

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# %%
def calc_tss(y_true=None, y_predict=None):
    """
    Calculates the true skill score for binary classification based on the output of the confusion
    table function
    """
    scores = confusion_matrix(y_true, y_predict).ravel()
    TN, FP, FN, TP = scores
    print('TN={0}\tFP={1}\tFN={2}\tTP={3}'.format(TN, FP, FN, TP))
    tp_rate = TP / float(TP + FN) if TP > 0 else 0  
    fp_rate = FP / float(FP + TN) if FP > 0 else 0
    
    return tp_rate - fp_rate

# %% [markdown]
# As in the previous assignment, we will be utilizing a binary classification of our 5 class dataset. So, below is the helper function to change our class labels from the 5 class target feature to the binary target feature. The function is implemented to take a dataframe (e.g. our `abt`) and prepares it for a binary classification by merging the `X`- and `M`-class samples into one group, and the rest (`NF`, `B`, and `C`) into another group, labeled with `1`s and `0`s, respectively.

# %%
def dichotomize_X_y(data: pd.DataFrame):
    """
    dichotomizes the dataset and split it into the features (X) and the labels (y).
    
    :return: two np.ndarray objects X and y.
    """
    data_dich = data.copy()
    

    data_dich['lab'] = data_dich['lab'].map({'NF': 0, 'B': 0, 'C': 0, 'M': 1, 'X': 1})
    
    y = data_dich['lab']
    X = data_dich.drop(['lab'], axis=1)
    return X.values, y.values

# %%
# %%time
data_dir = r'E:\OneDrive\Documents\School\GSU\Fall 2021\Intro DS\hw5\Data-Science-Model-Evaluation\data\FDS'
data_file = "normalized_partition1ExtractedFeatures.csv"
data_file2 = "normalized_partition2ExtractedFeatures.csv"
# data_file = "toy_normalized_partition1ExtractedFeatures.csv"
# data_file2 = "toy_normalized_partition2ExtractedFeatures.csv"
# Out:
# Wall time: 0 ns

# %%
# %%time
abt = pd.read_csv(os.path.join(data_dir, data_file))
abt2 = pd.read_csv(os.path.join(data_dir, data_file2))
# Out:
# Wall time: 23.8 s

# %%
# %%time
display(abt.head())
display(abt2.head())
# Out:
#   lab  TOTUSJH_var  TOTUSJH_difference_of_vars  TOTBSQ_min  TOTBSQ_max  \
# 0  NF     0.703435                    0.691661    0.878752    0.886776
# 1  NF     0.536687                    0.369924    0.827467    0.837925
# 2  NF     0.593047                    0.551995    0.831203    0.843844
# 3  NF     0.646995                    0.467533    0.924507    0.925464
# 4  NF     0.508972                    0.470260    0.863690    0.867887
#
#    TOTBSQ_median  TOTBSQ_mean  TOTBSQ_var  TOTBSQ_difference_of_mins  \
# 0       0.880269     0.880795    0.838756                   0.731461
# 1       0.832165     0.832613    0.805319                   0.805999
# 2       0.835858     0.837174    0.819294                   0.806446
# 3       0.924840     0.924978    0.843487                   0.825663
# 4       0.866987     0.866551    0.803660                   0.806323
#
#    TOTBSQ_difference_of_maxs  ...  TOTUSJZ_slope_of_longest_mono_decrease  \
# 0                   0.849843  ...                                0.988157
# 1                   0.814957  ...                                0.974288
# 2                   0.828374  ...                                0.974871
# 3                   0.754150  ...                                0.999076
# 4                   0.791700  ...                                0.997272
#
#    TOTUSJZ_gderivative_stddev  MEANPOT_max  MEANPOT_gderivative_mean  \
# 0                    0.019057     0.000029                  0.322544
# 1                    0.002260     0.000028                  0.322542
# 2                    0.007661     0.000025                  0.322542
# 3                    0.010761     0.000087                  0.322539
# 4                    0.004687     0.000122                  0.322533
#
#    TOTFX_stddev  SAVNCPP_slope_of_longest_mono_decrease  \
# 0      0.049426                                0.932794
# 1      0.014624                                0.987151
# 2      0.030668                                0.949625
# 3      0.055006                                0.938782
# 4      0.014136                                0.985678
#
#    TOTPOT_avg_mono_decrease_slope  USFLUX_stddev  TOTBSQ_dderivative_stddev  \
# 0                        0.999939       0.051082                   0.017805
# 1                        0.999982       0.013241                   0.003582
# 2                        0.999962       0.027575                   0.006493
# 3                        0.999863       0.052563                   0.018347
# 4                        0.999949       0.014227                   0.005817
#
#    Unnamed: 0
# 0    0.000000
# 1    0.000011
# 2    0.000023
# 3    0.000034
# 4    0.000045
#
# [5 rows x 722 columns]
#   lab  TOTUSJH_var  TOTUSJH_difference_of_vars  TOTBSQ_min  TOTBSQ_max  \
# 0  NF     0.625650                    0.454325    0.908213    0.910396
# 1  NF     0.524445                    0.504175    0.850718    0.859605
# 2  NF     0.542118                    0.443569    0.859713    0.863722
# 3  NF     0.690086                    0.573470    0.908204    0.913040
# 4  NF     0.447053                    0.475432    0.837674    0.842784
#
#    TOTBSQ_median  TOTBSQ_mean  TOTBSQ_var  TOTBSQ_difference_of_mins  \
# 0       0.909642     0.909491    0.846593                   0.862992
# 1       0.854693     0.855314    0.819748                   0.804913
# 2       0.862510     0.862245    0.798094                   0.825772
# 3       0.911105     0.910958    0.870655                   0.879251
# 4       0.840337     0.840142    0.782502                   0.780748
#
#    TOTBSQ_difference_of_maxs  ...  TOTUSJZ_slope_of_longest_mono_decrease  \
# 0                   0.844319  ...                                0.979902
# 1                   0.826852  ...                                0.966216
# 2                   0.797749  ...                                0.995778
# 3                   0.866121  ...                                0.895906
# 4                   0.776331  ...                                0.989757
#
#    TOTUSJZ_gderivative_stddev  MEANPOT_max  MEANPOT_gderivative_mean  \
# 0                    0.010545     0.000188                  0.322561
# 1                    0.004931     0.000023                  0.322544
# 2                    0.006140     0.000048                  0.322542
# 3                    0.007135     0.000083                  0.322527
# 4                    0.002271     0.000078                  0.322537
#
#    TOTFX_stddev  SAVNCPP_slope_of_longest_mono_decrease  \
# 0      0.065944                                0.987276
# 1      0.033646                                0.987473
# 2      0.017955                                0.960069
# 3      0.050694                                0.923701
# 4      0.006539                                0.982049
#
#    TOTPOT_avg_mono_decrease_slope  USFLUX_stddev  TOTBSQ_dderivative_stddev  \
# 0                        0.999920       0.023419                   0.010664
# 1                        0.999975       0.030375                   0.008006
# 2                        0.999959       0.010119                   0.009092
# 3                        0.999885       0.025038                   0.011711
# 4                        0.999969       0.006024                   0.003995
#
#    Unnamed: 0
# 0    0.000000
# 1    0.000011
# 2    0.000023
# 3    0.000034
# 4    0.000045
#
# [5 rows x 722 columns]
# Wall time: 44 ms

# %% [markdown]
# ---
# ### Q1 (10 points)
#
# Just like you did with the previous assignment, you will be utilizing a few different types of feature selection to find subsets of descriptive features to use in the models we will be evaluating.  For this question you will again be utilizing the [SelectKBest](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html#sklearn.feature_selection.SelectKBest) class from [scikit-learn Univariate Feature Selection](https://scikit-learn.org/stable/modules/feature_selection.html#univariate-feature-selection). You will then be using 3 diferent feature evaluation functions.
#
# -  [scikit-learn f_classif](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_classif.html#sklearn.feature_selection.f_classif)
#
# - [scikit-learn mutual_info_classif](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_classif.html#sklearn.feature_selection.mutual_info_classif)
#
# - [chi2](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.chi2.html#sklearn.feature_selection.chi2)
#
# For each of these combinations of evaluation functions, you need to construct a 20 feature training and testing dataset. This will be done by:
# <ol>
#     <li>Use the `SelectKBest` class with each of the evaluation functions to perform feature selection using Partition 1 as your input data</li>
#     <li>Construct a new train `DataFrame` for each instance of `SelectKBest` from 1 with the `lab` class labels using Partition 1</li>
#     <li>Construct a new test `DataFrame` for each instance of `SelectKBest` from 1 with the `lab` class labels using Partition 2</li>
# </ol>
#
# After this question, you should have a total of 6 `DataFrame`s to use in later questions, a train and test pair for each feature selection method.
#
# ---

# %%
# %%time
numFeat = 20
abt_cpy = abt.copy()
abt2_cpy = abt2.copy()

abt_cpy['lab'] = abt_cpy['lab'].map({'NF': 0, 'B': 0, 'C': 0, 'M': 1, 'X': 1}) 
y_train = abt_cpy['lab'].copy()
# Out:
# Wall time: 265 ms

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------
# f-classif train
f_classif_train = SelectKBest(f_classif, k=numFeat).fit(abt_cpy.loc[:, abt_cpy.columns != 'lab'], y_train)
cols = f_classif_train.get_support(indices=True)
f_classif_train = abt.iloc[:, [i+1 for i in cols]] # +1 for missing 'lab' col
f_classif_train.insert(0, 'lab', abt['lab']) 
# display(f_classif_train.head())

# f-clasif test
f_classif_test = abt2_cpy[f_classif_train.columns]
# display(f_classif_test.head())


# mutual_info_classif train
mutual_info_classif_train = SelectKBest(mutual_info_classif, k=numFeat).fit(abt_cpy.loc[:, abt_cpy.columns != 'lab'],\
                                                                            y_train)
cols = mutual_info_classif_train.get_support(indices=True)
mutual_info_classif_train = abt.iloc[:, [i+1 for i in cols]] # +1 for missing 'lab' col
mutual_info_classif_train.insert(0, 'lab', abt['lab'])
# display(mutual_info_classif_train.head())

# mutual_info_classif test
mutual_info_classif_test = abt2_cpy[mutual_info_classif_train.columns]
# display(mutual_info_classif_test.head())


# chi2 train
chi2_train = SelectKBest(chi2, k=numFeat).fit(abt_cpy.loc[:, abt_cpy.columns != 'lab'], y_train)
cols = chi2_train.get_support(indices=True)
chi2_train = abt.iloc[:, [i+1 for i in cols]] # +1 for missing 'lab' col
chi2_train.insert(0, 'lab', abt['lab'])
# display(chi2_train.head())

# chi2 test
chi2_test = abt2_cpy[chi2_train.columns]
# display(chi2_test.head())
# Out:
# Wall time: 6min 47s

# %% [markdown]
# ---
# ### Q2 (10 points)
#
# Now that we have our training and testing datasets for each of our feature subsets, we need to attempt to perform hyperparameter tuning on our model for each of the datasets. We want to see which combination of dataset and parameter settings seem to provide the best results.
#
# In order to do this, we must first dichotomize the training and testing data. Lucky for you, a method has already been provided to do this. All you need to do is apply it to teach of the `DataFrame`s you constructed in Q1.
#
# With your binary classification dataset constructed, now it's time to start training and testing some models. We will start with the simple [KNeighborsClassifer](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html), and try several different settings to see how/if using different settings will improve our score. So, for each of your three copies of the Partition 1 training datasets that have had their `lab` columns converted to a binary label, train 4 different instances with the following settings. **(see documentation to know what these are)** In total you will train and evaluate 12 model setting and feature selected data pairings.
#
# |Model Number| n_neighbors | p |
# |------------|-------------|---|
# |1|3|1|
# |2|3|2|
# |3|5|1|
# |4|5|2|
#
#
# Once you have done that, test each of your models using your binary classification copy of the Partition 2 testing dataset that was cunstructed with the same features the model was trained on. You shall then calculate and print the TSS score for each result. **NOTE: The model does take a little while to evaluate.**
#
# ---

# %%
# %%time
n_neighbors = [3, 5]
p = [1,2]
temp = [n_neighbors, p]
params = list(itertools.product(*temp))

# f-classif dich
X_f_classif_train, y_f_classif_train = dichotomize_X_y(f_classif_train)
X_f_classif_test, y_f_classif_test = dichotomize_X_y(f_classif_test)

# mutual_info_classif dich
X_mutual_info_classif_train, y_mutual_info_classif_train = dichotomize_X_y(mutual_info_classif_train)
X_mutual_info_classif_test, y_mutual_info_classif_test = dichotomize_X_y(mutual_info_classif_test) 

# chi2
X_chi2_train, y_chi2_train = dichotomize_X_y(chi2_train)
X_chi2_test, y_chi2_test = dichotomize_X_y(chi2_test)
# Out:
# Wall time: 80 ms

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------
# f-classif
for i, v in enumerate(params):
    # using globals to retain models after loop, not sure if I'll need later or not(edit: I didn't oops lol)
    #train
    globals()[f'f_classif_train_model_{i}'] = KNeighborsClassifier(n_neighbors=v[0], p=v[1])\
                                             .fit(X_f_classif_train, y_f_classif_train)
    #predict
    globals()[f'f_classif_pred_model_{i}'] = globals()[f'f_classif_train_model_{i}']\
                                            .predict(X_f_classif_test)
    
    #print tss score:
    if i == 0:
        print('f-classifier scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_f_classif_test, globals()[f'f_classif_pred_model_{i}'])
    print(f'tss: {score}\n')





# mutual_info_classif
for i, v in enumerate(params):
    #train
    globals()[f'mutual_info_classif_train_model_{i}'] = KNeighborsClassifier(n_neighbors=v[0], p=v[1])\
                                                        .fit(X_mutual_info_classif_train, y_mutual_info_classif_train)
    #predict
    globals()[f'mutual_info_classif_pred_model_{i}'] = globals()[f'mutual_info_classif_train_model_{i}']\
                                                      .predict(X_mutual_info_classif_test)
    
    #print tss score:
    if i == 0:
        print('\nmutual_info_classif scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_mutual_info_classif_test, globals()[f'mutual_info_classif_pred_model_{i}'])
    print(f'tss: {score}\n')

# chi2
for i, v in enumerate(params):
    #train
    globals()[f'chi2_train_model_{i}'] = KNeighborsClassifier(n_neighbors=v[0], p=v[1])\
                                        .fit(X_chi2_train, y_chi2_train)
    #predict
    globals()[f'chi2_pred_model_{i}'] = globals()[f'chi2_train_model_{i}']\
                                       .predict(X_chi2_test)
    
    #print tss score:
    if i == 0:
        print('\nchi2 scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_chi2_test, globals()[f'chi2_pred_model_{i}'])
    print(f'tss: {score}\n')
# Out:
# f-classifier scores:
# Model 1:
# TN=86117	FP=1039	FN=1048	TP=353
# tss: 0.2400417307792284
#
# Model 2:
# TN=86117	FP=1039	FN=1042	TP=359
# tss: 0.24432438602548112
#
# Model 3:
# TN=86251	FP=905	FN=1064	TP=337
# tss: 0.23015878982607474
#
# Model 4:
# TN=86227	FP=929	FN=1065	TP=336
# tss: 0.22916964564659123
#
#
# mutual_info_classif scores:
# Model 1:
# TN=85998	FP=1158	FN=1098	TP=303
# tss: 0.2029875692142952
#
# Model 2:
# TN=85981	FP=1175	FN=1103	TP=298
# tss: 0.19922363729296644
#
# Model 3:
# TN=86185	FP=971	FN=1113	TP=288
# tss: 0.19442650914263065
#
# Model 4:
# TN=86142	FP=1014	FN=1121	TP=280
# tss: 0.18822293393430845
#
#
# chi2 scores:
# Model 1:
# TN=86119	FP=1037	FN=1043	TP=358
# tss: 0.24363355750986468
#
# Model 2:
# TN=86130	FP=1026	FN=1075	TP=326
# tss: 0.22091894000302492
#
# Model 3:
# TN=86147	FP=1009	FN=1061	TP=340
# tss: 0.23110685479373275
#
# Model 4:
# TN=86208	FP=948	FN=1093	TP=308
# tss: 0.20896592125586816
#
# Wall time: 24min 27s

# %% [markdown]
# ---
# ### Q3 (10 points)
#
# After evaluating the various results from Q2, you will notice that the results are not all that great with greater than 1000 false negatives for nearly all of our settings tried. But, what can be done to improve our results? If you read the documentation for the [KNeighborsClassifer](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html), which you certainly should have, you will see that we were only using the `MinkowskiDistance` metric with different values of `p`. If you look into the [DistanceMetric](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.DistanceMetric.html#sklearn.neighbors.DistanceMetric) documentation for the neighbors classifiers, you will see there are several others available to use.
#
# So, for this question, train and evaluate two more instances of [KNeighborsClassifer](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) for each of our different feature selection train test datsets, but this time using the `ChebyshevDistance` metric instead of the `MinkowskiDistance` metric.  For these models you will only be changing the number neighbors to 3 and 5, as the values of `p` are not used for the `ChebyshevDistance` metric.
#
# ---

# %%
# %%time
n_neighbors = [3, 5]
temp = [n_neighbors]
params = list(itertools.product(*temp))

# # f-classif dich
# X_f_classif_train, y_f_classif_train = dichotomize_X_y(f_classif_train)
# X_f_classif_test, y_f_classif_test = dichotomize_X_y(f_classif_test)

# # mutual_info_classif dich
# X_mutual_info_classif_train, y_mutual_info_classif_train = dichotomize_X_y(mutual_info_classif_train)
# X_mutual_info_classif_test, y_mutual_info_classif_test = dichotomize_X_y(mutual_info_classif_test) 

# # chi2
# X_chi2_train, y_chi2_train = dichotomize_X_y(chi2_train)
# X_chi2_test, y_chi2_test = dichotomize_X_y(chi2_test)
# Out:
# Wall time: 0 ns

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------
#f-classif_chebyshev
for i, v in enumerate(params):
    # using globals to retain models after loop
    #train
    globals()[f'f_classif_train_model_{i}_chebyshev'] = KNeighborsClassifier(n_neighbors=v[0], metric='chebyshev')\
                                                       .fit(X_f_classif_train, y_f_classif_train)
    #predict
    globals()[f'f_classif_pred_model_{i}_chebyshev'] = globals()[f'f_classif_train_model_{i}_chebyshev']\
                                                      .predict(X_f_classif_test)
    
    #print tss score:
    if i == 0:
        print('f-classifier_chebyshev scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_f_classif_test, globals()[f'f_classif_pred_model_{i}_chebyshev'])
    print(f'tss: {score}\n')


# mutual_info_classif_chebyshev
for i, v in enumerate(params):
    #train
    globals()[f'mutual_info_classif_train_model_{i}_chebyshev'] = KNeighborsClassifier(n_neighbors=v[0],\
                                                                                       metric='chebyshev')\
                                                                 .fit(X_mutual_info_classif_train,\
                                                                      y_mutual_info_classif_train)
    #predict
    globals()[f'mutual_info_classif_pred_model_{i}_chebyshev'] = globals()[f'mutual_info_classif_train_model_{i}']\
                                                                .predict(X_mutual_info_classif_test)
    
    #print tss score:
    if i == 0:
        print('\nmutual_info_classif_chebyshev scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_mutual_info_classif_test, globals()[f'mutual_info_classif_pred_model_{i}_chebyshev'])
    print(f'tss: {score}\n')

# chi2_chebyshev
for i, v in enumerate(params):
    #train
    globals()[f'chi2_train_model_{i}_chebyshev'] = KNeighborsClassifier(n_neighbors=v[0], metric='chebyshev')\
                                                  .fit(X_chi2_train, y_chi2_train)
    #predict
    globals()[f'chi2_pred_model_{i}_chebyshev'] = globals()[f'chi2_train_model_{i}_chebyshev']\
                                                 .predict(X_chi2_test)
    
    #print tss score:
    if i == 0:
        print('\nchi2_chebyshev scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_chi2_test, globals()[f'chi2_pred_model_{i}_chebyshev'])
    print(f'tss: {score}\n')
# Out:
# f-classifier_chebyshev scores:
# Model 1:
# TN=86179	FP=977	FN=1086	TP=315
# tss: 0.21362961567449068
#
# Model 2:
# TN=86332	FP=824	FN=1111	TP=290
# tss: 0.19754069176016856
#
#
# mutual_info_classif_chebyshev scores:
# Model 1:
# TN=85998	FP=1158	FN=1098	TP=303
# tss: 0.2029875692142952
#
# Model 2:
# TN=85981	FP=1175	FN=1103	TP=298
# tss: 0.19922363729296644
#
#
# chi2_chebyshev scores:
# Model 1:
# TN=86266	FP=890	FN=1095	TP=306
# tss: 0.20820384291112848
#
# Model 2:
# TN=86357	FP=799	FN=1120	TP=281
# tss: 0.19140355087527713
#
# Wall time: 15min 1s

# %% [markdown]
# ---
# ### Q4 (10 points)
#
# After evaluating the results from Q3, you will see that the results are no better than those we found for Q2. This leads to the thought that maybe the [KNeighborsClassifer](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) is just not a good fit for the problem we are applying it to. So, let's move on to another classifier for this problem.
#
# In this question, you will utilize the [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html), and try several different settings to see how/if using different settings will improve our score. So, continuing to use our training/testing pairs constructed with different feature selection methods that have had their `lab` column converted to a binary label, train 8 different instances with the following settings. **(see documentation to know what these are)**
#
# |Model Number| criterion | max_depth | splitter |
# |------------|---------|-------------|---|
# |1|gini|5|best|
# |2|gini|5|random|
# |3|gini|None|best|
# |4|gini|None|random|
# |5|entropy|5|best|
# |6|entropy|5|random|
# |7|entropy|None|best|
# |8|entropy|None|random|
#
#
#
# Once you have done that, test each of your models using your binary classification copy of the Partition 2 testing dataset that was cunstructed with the same features the model was trained on. You shall then calculate and print the TSS score for each result.
#
# ---

# %%
# %%time
criterion = ['gini', 'entropy']
depth = [5, None]
splitter = ['best', 'random']
temp = [criterion, depth, splitter]
params = list(itertools.product(*temp)) 
# print(params)

# # f-classif dich
# X_f_classif_train, y_f_classif_train = dichotomize_X_y(f_classif_train)
# X_f_classif_test, y_f_classif_test = dichotomize_X_y(f_classif_test)

# # mutual_info_classif dich
# X_mutual_info_classif_train, y_mutual_info_classif_train = dichotomize_X_y(mutual_info_classif_train)
# X_mutual_info_classif_test, y_mutual_info_classif_test = dichotomize_X_y(mutual_info_classif_test) 

# # chi2
# X_chi2_train, y_chi2_train = dichotomize_X_y(chi2_train)
# X_chi2_test, y_chi2_test = dichotomize_X_y(chi2_test)
# Out:
# Wall time: 0 ns

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------

#f-classif_DTC
for i, v in enumerate(params):
    # using globals to retain models after loop
    #train
    globals()[f'f_classif_train_model_{i}_DTC'] = DecisionTreeClassifier(criterion=v[0], max_depth=v[1], splitter=v[2])\
                                                 .fit(X_f_classif_train, y_f_classif_train)
    #predict
    globals()[f'f_classif_pred_model_{i}_DTC'] = globals()[f'f_classif_train_model_{i}_DTC']\
                                                .predict(X_f_classif_test)
    
    #print tss score:
    if i == 0:
        print('f-classifier_DTC scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_f_classif_test, globals()[f'f_classif_pred_model_{i}_DTC'])
    print(f'tss: {score}\n')
    
    
# mutual_info_classif_DTC
for i, v in enumerate(params):
    # using globals to retain models after loop
    #train
    globals()[f'mutual_info_classif_train_model_{i}_DTC'] = DecisionTreeClassifier(criterion=v[0],\
                                                                                   max_depth=v[1],\
                                                                                   splitter=v[2])\
                                                           .fit(X_mutual_info_classif_train, y_mutual_info_classif_train)
    #predict
    globals()[f'mutual_info_classif_pred_model_{i}_DTC'] = globals()[f'mutual_info_classif_train_model_{i}_DTC']\
                                                          .predict(X_mutual_info_classif_test)
    
    #print tss score:
    if i == 0:
        print('\nmutual_info_classif_DTC scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_mutual_info_classif_test, globals()[f'mutual_info_classif_pred_model_{i}_DTC'])
    print(f'tss: {score}\n')
    
    
# chi2_DTC
for i, v in enumerate(params):
    # using globals to retain models after loop
    #train
    globals()[f'chi2_train_model_{i}_DTC'] = DecisionTreeClassifier(criterion=v[0], max_depth=v[1], splitter=v[2])\
                                            .fit(X_chi2_train, y_chi2_train)
    #predict
    globals()[f'chi2_pred_model_{i}_DTC'] = globals()[f'chi2_train_model_{i}_DTC']\
                                           .predict(X_chi2_test)
    
    #print tss score:
    if i == 0:
        print('\nchi2_DTC scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_chi2_test, globals()[f'chi2_pred_model_{i}_DTC'])
    print(f'tss: {score}\n')
    
    
    
# These weren't an improvement ??? 
# most are worse
# negative value??
# Out:
# f-classifier_DTC scores:
# Model 1:
# TN=86703	FP=453	FN=1146	TP=255
# tss: 0.1768152712068237
#
# Model 2:
# TN=86658	FP=498	FN=1131	TP=270
# tss: 0.18700559375037776
#
# Model 3:
# TN=86005	FP=1151	FN=1121	TP=280
# tss: 0.18665103985931647
#
# Model 4:
# TN=85794	FP=1362	FN=1103	TP=298
# tss: 0.1970780592489993
#
# Model 5:
# TN=86797	FP=359	FN=1251	TP=150
# tss: 0.1029473302590752
#
# Model 6:
# TN=86987	FP=169	FN=1260	TP=141
# tss: 0.09870334647180182
#
# Model 7:
# TN=85935	FP=1221	FN=1035	TP=366
# tss: 0.24723260749903958
#
# Model 8:
# TN=85883	FP=1273	FN=1058	TP=343
# tss: 0.23021913106067016
#
#
# mutual_info_classif_DTC scores:
# Model 1:
# TN=86722	FP=434	FN=1229	TP=172
# tss: 0.11778987354187226
#
# Model 2:
# TN=87089	FP=67	FN=1400	TP=1
# tss: -5.4960644051282957e-05
#
# Model 3:
# TN=85709	FP=1447	FN=1070	TP=331
# tss: 0.2196574003561312
#
# Model 4:
# TN=85476	FP=1680	FN=1077	TP=324
# tss: 0.2119876019400788
#
# Model 5:
# TN=86936	FP=220	FN=1324	TP=77
# tss: 0.0524365328634186
#
# Model 6:
# TN=87103	FP=53	FN=1400	TP=1
# tss: 0.00010567086726176488
#
# Model 7:
# TN=85776	FP=1380	FN=1056	TP=345
# tss: 0.23041899911581418
#
# Model 8:
# TN=85656	FP=1500	FN=1108	TP=293
# tss: 0.19192581212275056
#
#
# chi2_DTC scores:
# Model 1:
# TN=86337	FP=819	FN=1153	TP=248
# tss: 0.16761947343329733
#
# Model 2:
# TN=86913	FP=243	FN=1276	TP=125
# tss: 0.08643388020771144
#
# Model 3:
# TN=85835	FP=1321	FN=1035	TP=366
# tss: 0.24608523956108924
#
# Model 4:
# TN=85683	FP=1473	FN=992	TP=409
# tss: 0.27503360289354895
#
# Model 5:
# TN=86695	FP=461	FN=1172	TP=229
# tss: 0.1581653090380261
#
# Model 6:
# TN=86883	FP=273	FN=1185	TP=216
# tss: 0.15104327439449192
#
# Model 7:
# TN=85927	FP=1229	FN=1073	TP=328
# tss: 0.2200173348377366
#
# Model 8:
# TN=85699	FP=1457	FN=962	TP=439
# tss: 0.29663045799488436
#
# Wall time: 11.9 s

# %% [markdown]
# ---
# ### Q5 (10 points)
#
# After evaluating results from Q4, you will see that the [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html) was able to accomplish a bit of an improvement over the best resutls we found for the [KNeighborsClassifer](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html).  This is indeed great, but can we do better than this if we use yet another classifier? Let's move on to yet another and find out.
#
# For this question you will be utilizing the [GaussianNB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html) classifier. We won't be changing any of the default settings, just train 1 model for each of our feature selected data subsets. You will again be using your training/testing pairs constructed with different feature selection methods that have had their `lab` column converted to a binary label. You will then test each of your models using your binary classification copy of the Partition 2 testing dataset that was cunstructed with the same features the model was trained on. You shall then calculate and print the TSS score for each result.
#
# ---

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------

#f-classif_GNB
#train
f_classif_train_GNB = GaussianNB().fit(X_f_classif_train, y_f_classif_train)
#predict
f_classif_pred_GNB = f_classif_train_GNB.predict(X_f_classif_test)

#print tss score:
print('f-classifier_GNB scores: ')
score = calc_tss(y_f_classif_test, f_classif_pred_GNB)
print(f'tss: {score}\n')


#mutual_info_classif_GNB
#train
mutual_info_classif_train_GNB = GaussianNB().fit(X_mutual_info_classif_train, y_mutual_info_classif_train)
#predict
mutual_info_classif_pred_GNB = mutual_info_classif_train_GNB.predict(X_mutual_info_classif_test)

#print tss score:
print('mutual_info_classif_GNB scores: ')
score = calc_tss(y_mutual_info_classif_test, mutual_info_classif_pred_GNB)
print(f'tss: {score}\n')


#chi2_GNB
#train
chi2_train_GNB = GaussianNB().fit(X_chi2_train, y_chi2_train)
#predict
chi2_pred_GNB = chi2_train_GNB.predict(X_chi2_test)

#print tss score:
print('chi2_GNB scores: ')
score = calc_tss(y_chi2_test, chi2_pred_GNB)
print(f'tss: {score}\n')
# Out:
# f-classifier_GNB scores:
# TN=80749	FP=6407	FN=203	TP=1198
# tss: 0.7815916337173061
#
# mutual_info_classif_GNB scores:
# TN=74382	FP=12774	FN=110	TP=1291
# tss: 0.7749198734249243
#
# chi2_GNB scores:
# TN=77904	FP=9252	FN=99	TP=1302
# tss: 0.8231817068176652
#
# Wall time: 351 ms

# %% [markdown]
# ---
# ### Q6 (10 points)
#
# If you recall from a lecture some time back, it was shown that another way of improving the results of classification is to perform some form of sampling to balance the number of samples there are for the various classes. The reason why this works for specific classifiers, and methods for doing the sampling, are numerious and we don't have enough time to cover all of them in this course.  However, it is still beneficial to know this works and that it is something that you should be considering when you are training models.
#
# So, for this question, we will implement a very naive method for sampling so we can use the results for training our models again.  Below you will find a function stub, complete the function and have it return a copy of the input dataframe where each class (except for the smallest one) have been undersampled to match the size of the smallest class in the dataset. In this function you should assume the `lab` column is the class label and not the dicotomized binary classification converted label.
#
# To do this you may want to use the [groupby](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html) function of the DataFrame to get groups of rows from your DataFrame.  You may also wish to use the [sample](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sample.html) function to select a number of rows from a group. You can also use the [apply](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html) method to process each group from your grouped rows. These are just hints, you can solve the problem how you see fit.
#
# Once this function is complete, apply it to each of your training datasets that have been constructed with different feature selection methods from partition 1 (the ones with all the NF, C, .., X labels). You will not be applying this to your testing sets. After you have your sampled feature selected datasets, you will then apply your function that converts the multi-class problem to a binary problem to each of the resultant selected subsets so we can use these new undersampled data for the next several questions.
#
# ---

# %%
def perform_under_sample(data:DataFrame)->DataFrame:
    #----------------------------------------------
    # TODO: Complete here.
    #----------------------------------------------
    data_cpy = data.copy()
    groups = data_cpy.groupby('lab')
    min_group_size = groups.size().min()
    return groups.apply(lambda x: x.sample(n=min_group_size))

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------
sampled_f_classif_train = perform_under_sample(f_classif_train)
sampled_mutual_info_classif_train = perform_under_sample(mutual_info_classif_train)
sampled_chi2_train = perform_under_sample(chi2_train)
# Out:
# Wall time: 122 ms

# %% [markdown]
# ---
# ### Q7
#
# For this question repeat what you did for Q2, but with your balanced binary classification datasets constructed in Q6, uese the [KNeighborsClassifer](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html), and try several different settings to see how/if using different settings will improve our score.
#
# So, train 4 different instances with the following settings for each of your feature selected subsets, for a total of 12 different evaluations. **(see documentation to know what these are)**
#
# |Model Number| n_neighbors | p |
# |------------|-------------|---|
# |1|3|1|
# |2|3|2|
# |3|5|1|
# |4|5|2|
#
#
# Once you have done that, test each of your models using your binary classification copy of Partition 2 testing dataset that was cunstructed with the same features the model was trained on (these should not have been balanced). You shall then calculate and print the TSS score for each result. **NOTE: The model now takes less time to evaluate!**
#
# ---

# %%
# %%time
n_neighbors = [3, 5]
p = [1,2]
temp = [n_neighbors, p]
params = list(itertools.product(*temp))

# f-classif dich
X_sampled_f_classif_train, y_sampled_f_classif_train = dichotomize_X_y(sampled_f_classif_train)
X_f_classif_test, y_f_classif_test = dichotomize_X_y(f_classif_test)

# mutual_info_classif dich
X_sampled_mutual_info_classif_train, y_sampled_mutual_info_classif_train=dichotomize_X_y(sampled_mutual_info_classif_train)
X_mutual_info_classif_test, y_mutual_info_classif_test = dichotomize_X_y(mutual_info_classif_test) 

# chi2
X_sampled_chi2_train, y_sampled_chi2_train = dichotomize_X_y(sampled_chi2_train)
X_chi2_test, y_chi2_test = dichotomize_X_y(chi2_test)
# Out:
# Wall time: 76 ms

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------
# f-classif
for i, v in enumerate(params):
    # using globals to retain models after loop, not sure if I'll need later or not(edit: I didn't oops lol)
    #train
    globals()[f'sampled_f_classif_train_model_{i}'] = KNeighborsClassifier(n_neighbors=v[0], p=v[1])\
                                                     .fit(X_sampled_f_classif_train, y_sampled_f_classif_train)
    #predict
    globals()[f'sampled_f_classif_pred_model_{i}'] = globals()[f'sampled_f_classif_train_model_{i}']\
                                                    .predict(X_f_classif_test)
    
    #print tss score:
    if i == 0:
        print('sampled_f-classifier scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_f_classif_test, globals()[f'sampled_f_classif_pred_model_{i}'])
    print(f'tss: {score}\n')





# mutual_info_classif
for i, v in enumerate(params):
    #train
    globals()[f'sampled_mutual_info_classif_train_model_{i}'] = KNeighborsClassifier(n_neighbors=v[0], p=v[1])\
                                                               .fit(X_sampled_mutual_info_classif_train,\
                                                                    y_sampled_mutual_info_classif_train)
    #predict
    globals()[f'sampled_mutual_info_classif_pred_model_{i}'] = globals()[f'sampled_mutual_info_classif_train_model_{i}']\
                                                              .predict(X_mutual_info_classif_test)
    
    #print tss score:
    if i == 0:
        print('\nsampled_mutual_info_classif scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_mutual_info_classif_test, globals()[f'sampled_mutual_info_classif_pred_model_{i}'])
    print(f'tss: {score}\n')

# chi2
for i, v in enumerate(params):
    #train
    globals()[f'sampled_chi2_train_model_{i}'] = KNeighborsClassifier(n_neighbors=v[0], p=v[1])\
                                                .fit(X_sampled_chi2_train, y_sampled_chi2_train)
    #predict
    globals()[f'sampled_chi2_pred_model_{i}'] = globals()[f'sampled_chi2_train_model_{i}']\
                                               .predict(X_chi2_test)
    
    #print tss score:
    if i == 0:
        print('\nsampled_chi2 scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_chi2_test, globals()[f'sampled_chi2_pred_model_{i}'])
    print(f'tss: {score}\n')
# Out:
# sampled_f-classifier scores:
# Model 1:
# TN=82477	FP=4679	FN=552	TP=849
# tss: 0.5523103715280573
#
# Model 2:
# TN=82220	FP=4936	FN=513	TP=888
# tss: 0.5771988950281672
#
# Model 3:
# TN=82334	FP=4822	FN=494	TP=907
# tss: 0.5920686360905641
#
# Model 4:
# TN=82310	FP=4846	FN=458	TP=943
# tss: 0.6174891992629721
#
#
# sampled_mutual_info_classif scores:
# Model 1:
# TN=81772	FP=5384	FN=460	TP=941
# tss: 0.6098888080080485
#
# Model 2:
# TN=81665	FP=5491	FN=490	TP=911
# tss: 0.5872478480831781
#
# Model 3:
# TN=81812	FP=5344	FN=419	TP=982
# tss: 0.6396125660326218
#
# Model 4:
# TN=81696	FP=5460	FN=444	TP=957
# tss: 0.6204372223652133
#
#
# sampled_chi2 scores:
# Model 1:
# TN=81984	FP=5172	FN=302	TP=1099
# tss: 0.7250978161878235
#
# Model 2:
# TN=81951	FP=5205	FN=287	TP=1114
# tss: 0.7354258228839317
#
# Model 3:
# TN=82027	FP=5129	FN=295	TP=1106
# tss: 0.7305876155217704
#
# Model 4:
# TN=81990	FP=5166	FN=309	TP=1092
# tss: 0.7201702271434725
#
# Wall time: 45.2 s

# %% [markdown]
# ---
# ### Q8
#
# After evaluating the various results from Q7, you will notice that some of the results are improved over the same experiments we conducted in Q2. Additionally, you should also notice a improvement in the speed at which the results were obtained. The question now is will we continue to see these improvements for all of our experiments? So, let's move on and see.
#
# For this question, you will repeat the experiments from Q3, but using the balanced binary classification datasets constructed in Q6. You will still be using the [KNeighborsClassifer](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) like you did in Q7, but you will again be changing from using the `MinkowskiDistance` metric with different values of `p` to using the `ChebyshevDistance` metric. You will construct two models for each of your feature selected datasets by changing the number neighbors to 3 and 5.
#
# Once you have done that, test each of your models using your binary classification copy of Partition 2 testing dataset that was cunstructed with the same features the model was trained on (these should not have been balanced), then calculate and print the TSS score for each result.
#
# ---

# %%
# %%time
n_neighbors = [3, 5]
temp = [n_neighbors]
params = list(itertools.product(*temp))

# # f-classif dich
# X_sampled_f_classif_train, y_sampled_f_classif_train = dichotomize_X_y(sampled_f_classif_train)
# X_f_classif_test, y_f_classif_test = dichotomize_X_y(f_classif_test)

# # mutual_info_classif dich
#X_sampled_mutual_info_classif_train,y_sampled_mutual_info_classif_train=dichotomize_X_y(sampled_mutual_info_classif_train)
# X_mutual_info_classif_test, y_mutual_info_classif_test = dichotomize_X_y(mutual_info_classif_test) 

# # chi2
# X_sampled_chi2_train, y_sampled_chi2_train = dichotomize_X_y(sampled_chi2_train)
# X_chi2_test, y_chi2_test = dichotomize_X_y(chi2_test)
# Out:
# Wall time: 0 ns

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------
#sampled_f-classif_chebyshev
for i, v in enumerate(params):
    # using globals to retain models after loop
    #train
    globals()[f'sampled_f_classif_train_model_{i}_chebyshev'] = KNeighborsClassifier(n_neighbors=v[0], metric='chebyshev')\
                                                               .fit(X_sampled_f_classif_train, y_sampled_f_classif_train)
    #predict
    globals()[f'sampled_f_classif_pred_model_{i}_chebyshev'] = globals()[f'sampled_f_classif_train_model_{i}_chebyshev']\
                                                              .predict(X_f_classif_test)
    
    #print tss score:
    if i == 0:
        print('sampled_f-classifier_chebyshev scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_f_classif_test, globals()[f'sampled_f_classif_pred_model_{i}_chebyshev'])
    print(f'tss: {score}\n')


# sampled_mutual_info_classif_chebyshev
for i, v in enumerate(params):
    #train
    globals()[f'sampled_mutual_info_classif_train_model_{i}_chebyshev'] = KNeighborsClassifier(n_neighbors=v[0],\
                                                                                               metric='chebyshev')\
                                                                         .fit(X_sampled_mutual_info_classif_train,\
                                                                              y_sampled_mutual_info_classif_train)
    #predict
    globals()[f'sampled_mutual_info_classif_pred_model_{i}_chebyshev'] = globals()[f'sampled_mutual_info_classif_train_model_{i}']\
                                                                        .predict(X_mutual_info_classif_test)
    
    #print tss score:
    if i == 0:
        print('\nsampled_mutual_info_classif_chebyshev scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_mutual_info_classif_test, globals()[f'sampled_mutual_info_classif_pred_model_{i}_chebyshev'])
    print(f'tss: {score}\n')

# sampled_chi2_chebyshev
for i, v in enumerate(params):
    #train
    globals()[f'sampled_chi2_train_model_{i}_chebyshev'] = KNeighborsClassifier(n_neighbors=v[0], metric='chebyshev')\
                                                          .fit(X_sampled_chi2_train, y_sampled_chi2_train)
    #predict
    globals()[f'sampled_chi2_pred_model_{i}_chebyshev'] = globals()[f'sampled_chi2_train_model_{i}_chebyshev']\
                                                         .predict(X_chi2_test)
    
    #print tss score:
    if i == 0:
        print('\nsampled_chi2_chebyshev scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_chi2_test, globals()[f'sampled_chi2_pred_model_{i}_chebyshev'])
    print(f'tss: {score}\n')
# Out:
# sampled_f-classifier_chebyshev scores:
# Model 1:
# TN=82227	FP=4929	FN=453	TP=948
# tss: 0.6201057632463506
#
# Model 2:
# TN=82412	FP=4744	FN=432	TP=969
# tss: 0.6372176872934431
#
#
# sampled_mutual_info_classif_chebyshev scores:
# Model 1:
# TN=81772	FP=5384	FN=460	TP=941
# tss: 0.6098888080080485
#
# Model 2:
# TN=81665	FP=5491	FN=490	TP=911
# tss: 0.5872478480831781
#
#
# sampled_chi2_chebyshev scores:
# Model 1:
# TN=82255	FP=4901	FN=328	TP=1073
# tss: 0.7096490105659073
#
# Model 2:
# TN=82288	FP=4868	FN=347	TP=1054
# tss: 0.6964659003722976
#
# Wall time: 21.5 s

# %% [markdown]
# ---
# ### Q9
#
# After evaluating the results of Q8 things are looking a little less encouraging, since none of those results look to be better than the results of Q7. However, the results from Q3 weren't really any better than Q2 in the first place, so not all is lost.  Let's continue on and see how things turn out with models like we used in Q4 since those were actaully an improvement over Q2 originally.
#
# So, in this question, you will utilize the [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html), like you did in Q4, and try several different settings to see how/if using different settings will improve our score. The difference will again be that you are now using the balanced binary classification datasets constructed in Q6 to train 8 different instances for each of your feature selected datasets using the following settings. **(see documentation to know what these are)**
#
# |Model Number| criterion | max_depth | splitter |
# |------------|---------|-------------|---|
# |1|gini|5|best|
# |2|gini|5|random|
# |3|gini|None|best|
# |4|gini|None|random|
# |5|entropy|5|best|
# |6|entropy|5|random|
# |7|entropy|None|best|
# |8|entropy|None|random|
#
#
#
# Once you have done that, test each of your models using your binary classification copy of copy of Partition 2 testing dataset that was cunstructed with the same features the model was trained on (this should not have been balanced), then calculate and print the TSS score for each result.
#
# ---

# %%
# %%time
criterion = ['gini', 'entropy']
depth = [5, None]
splitter = ['best', 'random']
temp = [criterion, depth, splitter]
params = list(itertools.product(*temp))

# # f-classif dich
# X_sampled_f_classif_train, y_sampled_f_classif_train = dichotomize_X_y(sampled_f_classif_train)
# X_f_classif_test, y_f_classif_test = dichotomize_X_y(f_classif_test)

# # mutual_info_classif dich
#X_sampled_mutual_info_classif_train,y_sampled_mutual_info_classif_train=dichotomize_X_y(sampled_mutual_info_classif_train)
# X_mutual_info_classif_test, y_mutual_info_classif_test = dichotomize_X_y(mutual_info_classif_test) 

# # chi2
# X_sampled_chi2_train, y_sampled_chi2_train = dichotomize_X_y(sampled_chi2_train)
# X_chi2_test, y_chi2_test = dichotomize_X_y(chi2_test)
# Out:
# Wall time: 0 ns

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------
#f-classif_DTC
for i, v in enumerate(params):
    # using globals to retain models after loop
    #train
    globals()[f'sampled_f_classif_train_model_{i}_DTC'] = DecisionTreeClassifier(criterion=v[0],\
                                                                                 max_depth=v[1],\
                                                                                 splitter=v[2])\
                                                         .fit(X_sampled_f_classif_train, y_sampled_f_classif_train)
    #predict
    globals()[f'sampled_f_classif_pred_model_{i}_DTC'] = globals()[f'sampled_f_classif_train_model_{i}_DTC']\
                                                        .predict(X_f_classif_test)
    
    #print tss score:
    if i == 0:
        print('sampled_f-classifier_DTC scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_f_classif_test, globals()[f'sampled_f_classif_pred_model_{i}_DTC'])
    print(f'tss: {score}\n')
    
    
# mutual_info_classif_DTC
for i, v in enumerate(params):
    # using globals to retain models after loop
    #train
    globals()[f'sampled_mutual_info_classif_train_model_{i}_DTC'] = DecisionTreeClassifier(criterion=v[0],\
                                                                                           max_depth=v[1],\
                                                                                           splitter=v[2])\
                                                                   .fit(X_sampled_mutual_info_classif_train,\
                                                                        y_sampled_mutual_info_classif_train)
    #predict
    globals()[f'sampled_mutual_info_classif_pred_model_{i}_DTC'] = globals()[f'sampled_mutual_info_classif_train_model_{i}_DTC']\
                                                                  .predict(X_mutual_info_classif_test)
    
    #print tss score:
    if i == 0:
        print('\nsampled_mutual_info_classif_DTC scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_mutual_info_classif_test, globals()[f'sampled_mutual_info_classif_pred_model_{i}_DTC'])
    print(f'tss: {score}\n')
    
    
# chi2_DTC
for i, v in enumerate(params):
    # using globals to retain models after loop
    #train
    globals()[f'sampled_chi2_train_model_{i}_DTC'] = DecisionTreeClassifier(criterion=v[0], max_depth=v[1], splitter=v[2])\
                                                    .fit(X_sampled_chi2_train, y_sampled_chi2_train)
    #predict
    globals()[f'sampled_chi2_pred_model_{i}_DTC'] = globals()[f'sampled_chi2_train_model_{i}_DTC']\
                                                   .predict(X_chi2_test)
    
    #print tss score:
    if i == 0:
        print('\nsampled_chi2_DTC scores: ')
    print(f'Model {i+1}: ')
    score = calc_tss(y_chi2_test, globals()[f'sampled_chi2_pred_model_{i}_DTC'])
    print(f'tss: {score}\n')
    
# why did this give expected results but not with full dataset ????????
# Out:
# sampled_f-classifier_DTC scores:
# Model 1:
# TN=82702	FP=4454	FN=564	TP=837
# tss: 0.5463266388959401
#
# Model 2:
# TN=81114	FP=6042	FN=245	TP=1156
# tss: 0.7558009399670561
#
# Model 3:
# TN=82180	FP=4976	FN=611	TP=790
# tss: 0.5067899121641933
#
# Model 4:
# TN=82556	FP=4600	FN=695	TP=706
# tss: 0.45114684216334916
#
# Model 5:
# TN=82182	FP=4974	FN=331	TP=1070
# tss: 0.7066701043480773
#
# Model 6:
# TN=82751	FP=4405	FN=480	TP=921
# tss: 0.6068460226330733
#
# Model 7:
# TN=82519	FP=4637	FN=509	TP=892
# tss: 0.5834846286601405
#
# Model 8:
# TN=82713	FP=4443	FN=639	TP=762
# tss: 0.4929196587909562
#
#
# sampled_mutual_info_classif_DTC scores:
# Model 1:
# TN=78849	FP=8307	FN=542	TP=859
# tss: 0.5178216214829733
#
# Model 2:
# TN=80829	FP=6327	FN=415	TP=986
# tss: 0.6311890427000717
#
# Model 3:
# TN=79749	FP=7407	FN=686	TP=715
# tss: 0.42536420701446215
#
# Model 4:
# TN=80383	FP=6773	FN=579	TP=822
# tss: 0.5090125382992401
#
# Model 5:
# TN=79984	FP=7172	FN=443	TP=958
# tss: 0.6015080591418789
#
# Model 6:
# TN=79168	FP=7988	FN=220	TP=1181
# tss: 0.7513175567539285
#
# Model 7:
# TN=80610	FP=6546	FN=699	TP=702
# tss: 0.4259639585933338
#
# Model 8:
# TN=81241	FP=5915	FN=600	TP=801
# tss: 0.5038676618449696
#
#
# sampled_chi2_DTC scores:
# Model 1:
# TN=84596	FP=2560	FN=544	TP=857
# tss: 0.5823333051282286
#
# Model 2:
# TN=82492	FP=4664	FN=316	TP=1085
# tss: 0.7209335830713551
#
# Model 3:
# TN=83192	FP=3964	FN=541	TP=860
# tss: 0.5683655869025321
#
# Model 4:
# TN=83125	FP=4031	FN=528	TP=873
# tss: 0.5768759367509863
#
# Model 5:
# TN=81712	FP=5444	FN=469	TP=932
# tss: 0.6027764043758992
#
# Model 6:
# TN=82870	FP=4286	FN=383	TP=1018
# tss: 0.6774476502936525
#
# Model 7:
# TN=82701	FP=4455	FN=610	TP=791
# tss: 0.5134814749952902
#
# Model 8:
# TN=82907	FP=4249	FN=438	TP=963
# tss: 0.6386145033400445
#
# Wall time: 1.31 s

# %% [markdown]
# ---
# ### Q10
#
# Unlike with [KNeighborsClassifer](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html), it seems that the sampling didn't really help much for the [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html).  Where before we saw a 3X improvement with the Decision Tree over the KNN classifier, we now see similar results for both classifiers.  Let's see how switching to the sampled data affectes our best performing classifier when we were using the full dataset.
#
# For this question you will again be utilizing the [GaussianNB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html) classifier as you did in Q5 but using your balanced binary classification dataset constructed in Q6 to train just 1 model for each feature selected dataset. Once you have done that, test the model using your binary classification copy of Partition 2 testing dataset that was cunstructed with the same features the model was trained on (this should not have been balanced), then calculate and print the TSS score.
#
# ---

# %%
# %%time
#----------------------------------------------
# TODO: Complete here.
#----------------------------------------------
#sampled_f-classif_GNB
#train
sampled_f_classif_train_GNB = GaussianNB().fit(X_sampled_f_classif_train, y_sampled_f_classif_train)
#predict
sampled_f_classif_pred_GNB = sampled_f_classif_train_GNB.predict(X_f_classif_test)

#print tss score:
print('sampled_f-classifier_GNB scores: ')
score = calc_tss(y_f_classif_test, sampled_f_classif_pred_GNB)
print(f'tss: {score}\n')


#sampled_mutual_info_classif_GNB
#train
sampled_mutual_info_classif_train_GNB = GaussianNB().fit(X_sampled_mutual_info_classif_train,\
                                                         y_sampled_mutual_info_classif_train)
#predict
sampled_mutual_info_classif_pred_GNB = sampled_mutual_info_classif_train_GNB.predict(X_mutual_info_classif_test)

#print tss score:
print('sampled_mutual_info_classif_GNB scores: ')
score = calc_tss(y_mutual_info_classif_test, sampled_mutual_info_classif_pred_GNB)
print(f'tss: {score}\n')


#chi2_GNB
#train
sampled_chi2_train_GNB = GaussianNB().fit(X_sampled_chi2_train, y_sampled_chi2_train)
#predict
sampled_chi2_pred_GNB = sampled_chi2_train_GNB.predict(X_chi2_test)

#print tss score:
print('sampled_chi2_GNB scores: ')
score = calc_tss(y_chi2_test, sampled_chi2_pred_GNB)
print(f'tss: {score}\n')
# Out:
# sampled_f-classifier_GNB scores:
# TN=84193	FP=2963	FN=478	TP=923
# tss: 0.6248186200470682
#
# sampled_mutual_info_classif_GNB scores:
# TN=76105	FP=11051	FN=211	TP=1190
# tss: 0.7225976596838887
#
# sampled_chi2_GNB scores:
# TN=81070	FP=6086	FN=166	TP=1235
# tss: 0.8116843921500181
#
# Wall time: 242 ms

# %% [markdown]
# Unfortunately, we don't see much improvement for our [GaussianNB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html) classifier.
#
# **Note:The TA would like you to turn in assignments that have been run and have results, so make sure to do a restart and run all from the kernel menu. Then make sure to save before you turn it in. You might find it necessary to use the toy dataset if you have time constraints.**
